# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dietplan.csv")
df.head(10)
# Out:
#    Unnamed: 0  age  weight(kg)  height(m) gender        BMI      BMR  \
# 0           1    2   16.097862   0.932025      F  18.531612  958.584
# 1           2    4   14.619374   0.916687      F  17.397496  932.383
# 2           4    4   17.899918   0.997288      F  17.997414  977.578
# 3           6    3   13.532880   1.022786      F  12.936609  944.689
# 4           8    4   17.039484   1.053977      M  15.338909  799.229
# 5          10    3   12.032662   1.078630      F  10.342285  939.781
# 6          13    2   17.794901   1.070393      M  15.531358  831.386
# 7          15    3   15.789179   0.912256      F  18.972577  947.560
# 8          19    3   13.300541   1.068686      F  11.645791  950.262
# 9          21    4   15.504307   0.900704      F  19.111207  938.161
#
#    activity_level  calories_to_maintain_weight  BMI_tags  Label
# 0             1.2                    1150.3008         8     13
# 1             1.7                    1585.0511         7      1
# ...

# %%
df.shape
# Out:
# (10726, 11)

# %%
df['activity_level'].unique()
# Out:
# array([1.2, 1.7, 1.9, 1.3, 1.5])

# %%
X = df.iloc[:,1:8].values

# %%
X
# Out:
# array([[2, 16.09786214997295, 0.9320248764873584, ...,
#         18.531611873353047, 958.584, 1.2],
#        [4, 14.619373955500556, 0.9166868820307404, ...,
#         17.39749587302515, 932.383, 1.7],
#        [4, 17.89991841561572, 0.9972877191242412, ..., 17.99741410238895,
#         977.578, 1.9],
#        ...,
#        [50, 97.76125888449096, 1.6318641589556724, ...,
#         36.71121662042562, 1635.925, 1.7],
#        [57, 96.82932429007332, 1.6312896969709088, ..., 36.38687130273,
#         1593.981, 1.3],
#        [63, 97.61518559101536, 1.6331681748771816, ...,
#         36.59784956259417, 1791.512, 1.2]], dtype=object)

# %%
Y = df['calories_to_maintain_weight']

# %%
Y
# Out:
# 0        1150.3008
# 1        1585.0511
# 2        1857.3982
# 3        1794.9091
# 4        1518.5351
#            ...
# 10721    1963.2002
# 10722    2504.8106
# 10723    2781.0725
# 10724    2072.1753
# 10725    2149.8144
# Name: calories_to_maintain_weight, Length: 10726, dtype: float64

# %%
X.shape
# Out:
# (10726, 7)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()

ct = ColumnTransformer(transformers=[('ohe',ohe,[3])],remainder='passthrough')

# %%
X_encoded = ct.fit_transform(X)

# %%
Y.shape
# Out:
# (10726,)

# %%
X_encoded.shape
# Out:
# (10726, 8)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_encoded, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train[:, [1,2,4,5,6]] = sc.fit_transform(X_train[:, [1,2,4,5,6]])
X_test[:, [1,2,4,5,6]] = sc.transform(X_test[:, [1,2,4,5,6]])

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

linreg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import BayesianRidge

brreg = BayesianRidge()

brreg.fit(X_train, Y_train)
# Out:
# BayesianRidge()

# %%
from sklearn.tree import DecisionTreeRegressor

dtreg = DecisionTreeRegressor()

dtreg.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import accuracy_score


score1 = linreg.score(X_test, Y_test)
score2 = brreg.score(X_test, Y_test)
score3 = dtreg.score(X_test, Y_test)

print("Linear Regression-> ",score1)
print("Bayesian Regression> ",score2)
print("Decision Tree Regression-> ",score3)
# Out:
# Linear Regression->  0.9869925586742293
# Bayesian Regression>  0.9869884507567307
# Decision Tree Regression->  0.9999000004628383
