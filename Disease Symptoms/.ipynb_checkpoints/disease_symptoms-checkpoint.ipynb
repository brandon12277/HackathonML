# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DiseaseAndSymptoms.csv")
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
s1 = df.Symptom_1.unique()
len(s1)
# Out:
# 34

# %%
s2 = df.Symptom_2.unique()
len(s2)
# Out:
# 48

# %%
s3 = df.Symptom_3.unique()
len(s3)
# Out:
# 54

# %%
s4 = df.Symptom_4.unique()
len(s4)
# Out:
# 51

# %%
s5 = df.Symptom_5.unique()
len(s5)
# Out:
# 39

# %%
s6 = df.Symptom_6.unique()
len(s6)
# Out:
# 33

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
X = df.iloc[:,1:7]
Y = df.Disease

# %%
X.columns
# Out:
# Index(['Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5',
#        'Symptom_6'],
#       dtype='object')

# %%
X.isnull().sum()
# Out:
# Symptom_1       0
# Symptom_2       0
# Symptom_3       0
# Symptom_4     348
# Symptom_5    1206
# Symptom_6    1986
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in X.columns:
    if X[col].isnull().any():
        
        mask = X[col].notnull()
        X.loc[mask, col] = le.fit_transform(X.loc[mask, col])
    else:
        
        X[col] = le.fit_transform(X[col])

Y = le.fit_transform(Y)

X
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_9764\3752527729.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col])
# C:\Users\biswa\AppData\Local\Temp\ipykernel_9764\3752527729.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col])
# C:\Users\biswa\AppData\Local\Temp\ipykernel_9764\3752527729.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X.isnull().sum()
# Out:
# Symptom_1    0
# Symptom_2    0
# Symptom_3    0
# Symptom_4    0
# Symptom_5    0
# Symptom_6    0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

cols_2_imp = ['Symptom_4', 'Symptom_5', 'Symptom_6']

imp=KNNImputer(n_neighbors=2);

X[cols_2_imp] = imp.fit_transform(X[cols_2_imp])
# Out:
# C:\Users\biswa\AppData\Local\Temp\ipykernel_9764\1020184871.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[cols_2_imp] = imp.fit_transform(X[cols_2_imp])

# %%
X.isnull().sum()
# Out:
# Symptom_1    0
# Symptom_2    0
# Symptom_3    0
# Symptom_4    0
# Symptom_5    0
# Symptom_6    0
# dtype: int64

# %%
X
# Out:
#       Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6
# 0            33         35         35       11.0       15.0       11.0
# 1            24         27         18       25.0       19.0       16.0
# 2            33         27         18       25.0       19.0       16.0
# 3            33         35         18       25.0       19.0       16.0
# 4            33         35         35       25.0       19.0       16.0
# ...         ...        ...        ...        ...        ...        ...
# 4915         28         17         33       39.0       24.0       32.0
# 4916         24         31          3       36.0       32.0        7.0
# 4917          4          4         22        7.0        3.0        2.0
# 4918         24         20         42       37.0       29.0       15.0
# 4919         24         18          4       34.0       37.0       31.0
#
# [4920 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train , Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

dtclas = DecisionTreeClassifier()

dtclas.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = dtclas.predict(X_test)

acc = accuracy_score(y_pred, Y_test)

print("Accuracy: ",acc)
# Out:
# Accuracy:  0.9979674796747967

# %%
from joblib import dump

#LabelEncoder, model and knnimputer

dump(dtclas, 'model-disease.joblib')
dump(imp, 'knn-imputer.joblib')
dump(le, 'label-encode.joblib')
# Out:
# ['label-encode.joblib']
